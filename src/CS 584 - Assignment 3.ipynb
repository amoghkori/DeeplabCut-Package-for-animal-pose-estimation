# %%
# Load Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load Data
df = pd.read_csv("A20491465_CollectedData_annotation.csv")

# %%
df.head(10)
# Out:
#          scorer  Unnamed: 1  \
# 0   individuals         NaN
# 1     bodyparts         NaN
# 2        coords         NaN
# 3  labeled-data        37.0
# 4  labeled-data        37.0
# 5  labeled-data        37.0
# 6  labeled-data        37.0
# 7  labeled-data        37.0
# 8  labeled-data        37.0
# 9  labeled-data        37.0
#
#                                           Unnamed: 2          annotation  \
# 0                                                NaN              mouse1
# 1                                                NaN             topleft
# 2                                                NaN                   x
# 3  A_male_in_a_new_cage_face_view_3_2022-08-10_15...  148.10989315406638
# 4  A_male_in_a_new_cage_face_view_3_2022-08-10_15...   339.4582368850661
# 5  A_male_in_a_new_cage_face_view_3_2022-08-10_15...  245.84558714757745
# 6  A_male_in_a_new_cage_face_view_3_2022-08-10_15...   291.3325994622298
# ...

# %%
df = df.drop(df.columns[[0,1,2]], axis=1)

# %%
df
# Out:
#              annotation        annotation.1        annotation.2  \
# 0                mouse1              mouse1              mouse1
# 1               topleft             topleft           rightdown
# 2                     x                   y                   x
# 3    148.10989315406638  206.93089095376905   400.5342387963184
# 4     339.4582368850661   92.51527740552132  404.21744745842676
# ..                  ...                 ...                 ...
# 123   262.5930444919751  121.15895605059657   502.0781417724596
# 124  257.65677574325457  101.45588338620797  454.40858400074944
# 125  250.13818653187874   211.4231654461208   525.5150574726147
# 126    283.239375324372   166.2864121085855   451.7445522060624
# 127     345.69083814477  156.12390849188589   497.8157045797166
#
#            annotation.3        annotation.4        annotation.5  \
# 0                mouse1              mouse1              mouse1
# 1             rightdown                nose                nose
# ...

# %% [markdown]
# ## Replacing the columns names

# %%
df.columns = ['mouse1_topleft_x', 'mouse1_topleft_y', 'mouse1_rightdown_x',
       'mouse1_rightdown_y', 'mouse1_nose_x', 'mouse1_nose_y',
       'mouse1_leftear_x', 'mouse1_leftear_y', 'mouse1_rightear_x',
       'mouse1_rightear_y', 'mouse1_leftHip_x', 'mouse1_leftHip_y',
       'mouse1_rightHip_x', 'mouse1_rightHip_y', 'mouse1_tailbase_x',
       'mouse1_tailbase_y', 'mouse1_tailend_x', 'mouse1_tailend_y',
       'mouse2_topleft_x', 'mouse2_topleft_y', 'mouse2_rightdown_x',
       'mouse2_rightdown_y', 'mouse2_nose_x', 'mouse2_nose_y',
       'mouse2_leftear_x', 'mouse2_leftear_y', 'mouse2_rightear_x',
       'mouse2_rightear_y', 'mouse2_leftHip_x', 'mouse2_leftHip_y',
       'mouse2_rightHip_x', 'mouse2_rightHip_y', 'mouse2_tailBase_x',
       'mouse2_tailBase_y', 'mouse2_tailEnd_x', 'mouse2_tailEnd_y']

# %%
df.columns
# Out:
# Index(['mouse1_topleft_x', 'mouse1_topleft_y', 'mouse1_rightdown_x',
#        'mouse1_rightdown_y', 'mouse1_nose_x', 'mouse1_nose_y',
#        'mouse1_leftear_x', 'mouse1_leftear_y', 'mouse1_rightear_x',
#        'mouse1_rightear_y', 'mouse1_leftHip_x', 'mouse1_leftHip_y',
#        'mouse1_rightHip_x', 'mouse1_rightHip_y', 'mouse1_tailbase_x',
#        'mouse1_tailbase_y', 'mouse1_tailend_x', 'mouse1_tailend_y',
#        'mouse2_topleft_x', 'mouse2_topleft_y', 'mouse2_rightdown_x',
#        'mouse2_rightdown_y', 'mouse2_nose_x', 'mouse2_nose_y',
#        'mouse2_leftear_x', 'mouse2_leftear_y', 'mouse2_rightear_x',
#        'mouse2_rightear_y', 'mouse2_leftHip_x', 'mouse2_leftHip_y',
#        'mouse2_rightHip_x', 'mouse2_rightHip_y', 'mouse2_tailBase_x',
#        'mouse2_tailBase_y', 'mouse2_tailEnd_x', 'mouse2_tailEnd_y'],
#       dtype='object')

# %% [markdown]
# ## Removing the unwanted rows

# %%
df = df.drop([0,1,2], axis=0)

# %% [markdown]
# ## Creating a dataframe for Mouse 1

# %%
mouse1_df = df.iloc[:,:18]

# %%
mouse1_df
# Out:
#        mouse1_topleft_x    mouse1_topleft_y  mouse1_rightdown_x  \
# 3    148.10989315406638  206.93089095376905   400.5342387963184
# 4     339.4582368850661   92.51527740552132  404.21744745842676
# 5    245.84558714757745  154.77687161048442   361.7089260460609
# 6     291.3325994622298  179.19103611893897   408.2731404047057
# 7    306.58397064161096  171.01842817489486  402.42075566666165
# ..                  ...                 ...                 ...
# 123   262.5930444919751  121.15895605059657   502.0781417724596
# 124  257.65677574325457  101.45588338620797  454.40858400074944
# 125  250.13818653187874   211.4231654461208   525.5150574726147
# 126    283.239375324372   166.2864121085855   451.7445522060624
# 127     345.69083814477  156.12390849188589   497.8157045797166
#
#      mouse1_rightdown_y       mouse1_nose_x       mouse1_nose_y  \
# 3     326.8593851849386    198.233607855559  240.75727930605981
# 4    232.29940517786554  394.87517869693363  106.91360021048797
# ...

# %% [markdown]
# ## Creating a dataframe for Mouse 2

# %%
mouse2_df = df.iloc[:,18:]

# %%
mouse2_df
# Out:
#        mouse2_topleft_x    mouse2_topleft_y  mouse2_rightdown_x  \
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# 5                   NaN                 NaN                 NaN
# 6                   NaN                 NaN                 NaN
# 7                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 123  199.49846747229878  234.54693167270923   458.2300020665787
# 124  225.52596058113403  178.70009701277812  446.11086406196375
# 125   428.0229602181144   99.02097930565623   556.1458842839415
# 126                 NaN                 NaN                 NaN
# 127  490.38690562744927  262.43882331698177   634.5550106152225
#
#      mouse2_rightdown_y       mouse2_nose_x       mouse2_nose_y  \
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ...

# %%
mouse2_df.columns = ['mouse1_topleft_x', 'mouse1_topleft_y', 'mouse1_rightdown_x',
       'mouse1_rightdown_y', 'mouse1_nose_x', 'mouse1_nose_y',
       'mouse1_leftear_x', 'mouse1_leftear_y', 'mouse1_rightear_x',
       'mouse1_rightear_y', 'mouse1_leftHip_x', 'mouse1_leftHip_y',
       'mouse1_rightHip_x', 'mouse1_rightHip_y', 'mouse1_tailbase_x',
       'mouse1_tailbase_y', 'mouse1_tailend_x', 'mouse1_tailend_y']

# %%
mouse2_df
# Out:
#        mouse1_topleft_x    mouse1_topleft_y  mouse1_rightdown_x  \
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# 5                   NaN                 NaN                 NaN
# 6                   NaN                 NaN                 NaN
# 7                   NaN                 NaN                 NaN
# ..                  ...                 ...                 ...
# 123  199.49846747229878  234.54693167270923   458.2300020665787
# 124  225.52596058113403  178.70009701277812  446.11086406196375
# 125   428.0229602181144   99.02097930565623   556.1458842839415
# 126                 NaN                 NaN                 NaN
# 127  490.38690562744927  262.43882331698177   634.5550106152225
#
#      mouse1_rightdown_y       mouse1_nose_x       mouse1_nose_y  \
# 3                   NaN                 NaN                 NaN
# 4                   NaN                 NaN                 NaN
# ...

# %% [markdown]
# ## Combining both dataframe in one

# %%
concatenated_mouse_data = pd.concat([mouse1_df, mouse2_df], axis = 0 )

# %%
concatenated_mouse_data
# Out:
#        mouse1_topleft_x    mouse1_topleft_y  mouse1_rightdown_x  \
# 3    148.10989315406638  206.93089095376905   400.5342387963184
# 4     339.4582368850661   92.51527740552132  404.21744745842676
# 5    245.84558714757745  154.77687161048442   361.7089260460609
# 6     291.3325994622298  179.19103611893897   408.2731404047057
# 7    306.58397064161096  171.01842817489486  402.42075566666165
# ..                  ...                 ...                 ...
# 123  199.49846747229878  234.54693167270923   458.2300020665787
# 124  225.52596058113403  178.70009701277812  446.11086406196375
# 125   428.0229602181144   99.02097930565623   556.1458842839415
# 126                 NaN                 NaN                 NaN
# 127  490.38690562744927  262.43882331698177   634.5550106152225
#
#      mouse1_rightdown_y       mouse1_nose_x       mouse1_nose_y  \
# 3     326.8593851849386    198.233607855559  240.75727930605981
# 4    232.29940517786554  394.87517869693363  106.91360021048797
# ...

# %%
concatenated_mouse_data = concatenated_mouse_data.dropna()

# %%
concatenated_mouse_data.columns = ['mouse_topleft_x', 'mouse_topleft_y', 'mouse_rightdown_x',
       'mouse_rightdown_y', 'mouse_nose_x', 'mouse_nose_y',
       'mouse_leftear_x', 'mouse_leftear_y', 'mouse_rightear_x',
       'mouse_rightear_y', 'mouse_leftHip_x', 'mouse_leftHip_y',
       'mouse_rightHip_x', 'mouse_rightHip_y', 'mouse_tailbase_x',
       'mouse_tailbase_y', 'mouse_tailend_x', 'mouse_tailend_y']

# %%
concatenated_mouse_data.dtypes
# Out:
# mouse_topleft_x      object
# mouse_topleft_y      object
# mouse_rightdown_x    object
# mouse_rightdown_y    object
# mouse_nose_x         object
# mouse_nose_y         object
# mouse_leftear_x      object
# mouse_leftear_y      object
# mouse_rightear_x     object
# mouse_rightear_y     object
# mouse_leftHip_x      object
# mouse_leftHip_y      object
# mouse_rightHip_x     object
# mouse_rightHip_y     object
# mouse_tailbase_x     object
# mouse_tailbase_y     object
# mouse_tailend_x      object
# mouse_tailend_y      object
# dtype: object

# %% [markdown]
# ## Converting Object to float

# %%
concatenated_mouse_data = concatenated_mouse_data.astype(float)

# %%
concatenated_mouse_data.dtypes
# Out:
# mouse_topleft_x      float64
# mouse_topleft_y      float64
# mouse_rightdown_x    float64
# mouse_rightdown_y    float64
# mouse_nose_x         float64
# mouse_nose_y         float64
# mouse_leftear_x      float64
# mouse_leftear_y      float64
# mouse_rightear_x     float64
# mouse_rightear_y     float64
# mouse_leftHip_x      float64
# mouse_leftHip_y      float64
# mouse_rightHip_x     float64
# mouse_rightHip_y     float64
# mouse_tailbase_x     float64
# mouse_tailbase_y     float64
# mouse_tailend_x      float64
# mouse_tailend_y      float64
# dtype: object

# %%
concatenated_mouse_data["avg_cord_x"] = (concatenated_mouse_data["mouse_topleft_x"] + concatenated_mouse_data["mouse_rightdown_x"]) / 2
concatenated_mouse_data["avg_cord_y"] = (concatenated_mouse_data["mouse_topleft_y"] + concatenated_mouse_data["mouse_rightdown_y"]) / 2
concatenated_mouse_data
# Out:
#      mouse_topleft_x  mouse_topleft_y  mouse_rightdown_x  mouse_rightdown_y  \
# 3         148.109893       206.930891         400.534239         326.859385
# 4         339.458237        92.515277         404.217447         232.299405
# 5         245.845587       154.776872         361.708926         243.011260
# 6         291.332599       179.191036         408.273140         241.189998
# 7         306.583971       171.018428         402.420756         237.941742
# ..               ...              ...                ...                ...
# 122       358.678821       119.365051         545.861912         308.796588
# 123       199.498467       234.546932         458.230002         345.857810
# 124       225.525961       178.700097         446.110864         344.020688
# 125       428.022960        99.020979         556.145884         297.809640
# 127       490.386906       262.438823         634.555011         356.949025
#
# ...

# %%
concatenated_mouse_data.shape
# Out:
# (198, 20)

# %%
concatenated_mouse_data.describe()
# Out:
#        mouse_topleft_x  mouse_topleft_y  mouse_rightdown_x  mouse_rightdown_y  \
# count       198.000000       198.000000         198.000000         198.000000
# mean        220.390739       142.338446         427.215225         295.325803
# std         111.501012        64.762133         107.630270          44.838847
# min           6.508356        -0.465971         112.862820         147.742529
# 25%         138.730163        98.126517         361.205585         263.416640
# 50%         215.396813       162.967566         423.927964         309.742057
# 75%         292.131840       193.066344         517.884024         331.049370
# max         534.017133       268.857729         634.987726         357.934836
#
#        mouse_nose_x  mouse_nose_y  mouse_leftear_x  mouse_leftear_y  \
# count    198.000000    198.000000       198.000000       198.000000
# mean     317.861569    196.462504       314.803232       185.749820
# ...

# %% [markdown]
# ## Plot of mouse movement

# %%
concatenated_mouse_data.plot(x = 'avg_cord_x', y = 'avg_cord_y')
# Out:
# <AxesSubplot:xlabel='avg_cord_x'>

# %% [markdown]
# ## Test-Train Split

# %%
from sklearn.model_selection import train_test_split

# %%
X  = concatenated_mouse_data.iloc[: , 4:18]
Y  = concatenated_mouse_data.iloc[: , 18:]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y,random_state=100, test_size=0.30)

# %%
X_train.shape
# Out:
# (138, 14)

# %%
X_test.shape
# Out:
# (60, 14)

# %%
Y_train.shape
# Out:
# (138, 2)

# %%
Y_test.shape
# Out:
# (60, 2)

# %% [markdown]
# ## Building neural network

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
neural_model = Sequential()
neural_model.add(Dense(14, input_dim = 14, activation='relu'))
neural_model.add(Dense(14, activation = 'relu'))
neural_model.add(Dense(2))

# %% [markdown]
# """"
# # Save model
# model_json = neural_model.to_json()
# with open("neural_model.json", "w") as json_file:
#     json_file.write(model_json)
# neural_model.save_weights("ml_mouse_location.h5")
# """"

# %%
with open('neural_model.json','r') as f:
    json = f.read()
neural_model = tf.keras.models.model_from_json(json)

neural_model.load_weights("ml_mouse_location.h5")

# %%
neural_model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_41 (Dense)            (None, 14)                210
#
#  dense_42 (Dense)            (None, 14)                210
#
#  dense_43 (Dense)            (None, 2)                 30
#
# ...
# Total params: 450
# Trainable params: 450
# Non-trainable params: 0
# _________________________________________________________________

# %%
neural_model.compile(loss='mean_squared_error',optimizer='adam', metrics=['accuracy'])

# %%
neural_model.fit(X_train, Y_train, epochs = 100, validation_data = (X_test, Y_test))
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 51ms/step - loss: 271.3700 - accuracy: 0.9493 - val_loss: 348.9265 - val_accuracy: 0.9167
# Epoch 2/100
# 5/5 [==============================] - 0s 10ms/step - loss: 238.1915 - accuracy: 0.9420 - val_loss: 235.7049 - val_accuracy: 0.9167
# Epoch 3/100
# 5/5 [==============================] - 0s 9ms/step - loss: 260.6820 - accuracy: 0.9493 - val_loss: 255.0192 - val_accuracy: 0.9167
# Epoch 4/100
# 5/5 [==============================] - 0s 11ms/step - loss: 222.9242 - accuracy: 0.9565 - val_loss: 236.0434 - val_accuracy: 0.9167
# Epoch 5/100
# 5/5 [==============================] - 0s 10ms/step - loss: 210.5159 - accuracy: 0.9493 - val_loss: 196.8782 - val_accuracy: 0.9167
# Epoch 6/100
# 5/5 [==============================] - 0s 11ms/step - loss: 203.4512 - accuracy: 0.9420 - val_loss: 220.2769 - val_accuracy: 0.9167
# Epoch 7/100
# ...

# %%
accuracy = neural_model.evaluate(X_test, Y_test, verbose=0)
print(accuracy[1]*100)
# Out:
# 93.33333373069763

# %%
history = neural_model.fit(X_train, Y_train, epochs=100, batch_size=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/100
# 138/138 [==============================] - 0s 3ms/step - loss: 369.3966 - accuracy: 0.9348 - val_loss: 776.9754 - val_accuracy: 0.9167
# Epoch 2/100
# 138/138 [==============================] - 0s 2ms/step - loss: 279.8225 - accuracy: 0.9348 - val_loss: 464.4081 - val_accuracy: 0.9333
# Epoch 3/100
# 138/138 [==============================] - 0s 2ms/step - loss: 202.6628 - accuracy: 0.9565 - val_loss: 216.9460 - val_accuracy: 0.9167
# Epoch 4/100
# 138/138 [==============================] - 0s 3ms/step - loss: 229.6574 - accuracy: 0.9348 - val_loss: 144.1647 - val_accuracy: 0.9667
# Epoch 5/100
# 138/138 [==============================] - 0s 2ms/step - loss: 205.7796 - accuracy: 0.9493 - val_loss: 157.8824 - val_accuracy: 0.9167
# Epoch 6/100
# 138/138 [==============================] - 0s 2ms/step - loss: 198.3384 - accuracy: 0.9710 - val_loss: 144.7446 - val_accuracy: 0.9500
# Epoch 7/100
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
history = neural_model.fit(X_train, Y_train, epochs=200, batch_size=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/200
# 138/138 [==============================] - 0s 3ms/step - loss: 141.8227 - accuracy: 0.9783 - val_loss: 218.4406 - val_accuracy: 0.9000
# Epoch 2/200
# 138/138 [==============================] - 0s 2ms/step - loss: 163.8475 - accuracy: 0.9565 - val_loss: 349.6339 - val_accuracy: 0.9000
# Epoch 3/200
# 138/138 [==============================] - 0s 2ms/step - loss: 143.1822 - accuracy: 0.9493 - val_loss: 127.6079 - val_accuracy: 0.9500
# Epoch 4/200
# 138/138 [==============================] - 0s 2ms/step - loss: 115.5666 - accuracy: 0.9493 - val_loss: 121.6806 - val_accuracy: 0.9500
# Epoch 5/200
# 138/138 [==============================] - 0s 2ms/step - loss: 136.4131 - accuracy: 0.9565 - val_loss: 145.9279 - val_accuracy: 0.9167
# Epoch 6/200
# 138/138 [==============================] - 0s 2ms/step - loss: 134.1789 - accuracy: 0.9638 - val_loss: 113.6814 - val_accuracy: 0.9333
# Epoch 7/200
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
history = neural_model.fit(X_train, Y_train, epochs=250, batch_size=1, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/250
# 138/138 [==============================] - 0s 3ms/step - loss: 105.2720 - accuracy: 0.9783 - val_loss: 107.8240 - val_accuracy: 0.9500
# Epoch 2/250
# 138/138 [==============================] - 0s 2ms/step - loss: 116.5637 - accuracy: 0.9638 - val_loss: 136.9904 - val_accuracy: 0.9500
# Epoch 3/250
# 138/138 [==============================] - 0s 2ms/step - loss: 114.4271 - accuracy: 0.9710 - val_loss: 176.6846 - val_accuracy: 0.9167
# Epoch 4/250
# 138/138 [==============================] - 0s 2ms/step - loss: 107.1163 - accuracy: 0.9928 - val_loss: 111.8753 - val_accuracy: 0.9500
# Epoch 5/250
# 138/138 [==============================] - 0s 2ms/step - loss: 112.0814 - accuracy: 0.9710 - val_loss: 145.7925 - val_accuracy: 0.9167
# Epoch 6/250
# 138/138 [==============================] - 0s 2ms/step - loss: 103.3897 - accuracy: 0.9928 - val_loss: 141.1579 - val_accuracy: 0.9500
# Epoch 7/250
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
